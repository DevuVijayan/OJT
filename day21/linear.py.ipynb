# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
#dataset
height = np.array([150,160,164,165,173]).reshape(-1,1)
weight = np.array([50,65,63,68,72])
#create an linear regression model for the above data set
model = LinearRegression()
#lets fit the model with appropriate model
model.fit(height,weight)
predicted_weight = model.predict(height)
print(f"intercept: {model.intercept_}")
print(f"coefficients:{model.coef_[0]}")
# Out:
# intercept: -89.3285917496444
# coefficients:0.9416785206258891

# %%
#create a scatterplot for the above
plt.scatter(height,weight,color='cyan')
plt.plot(height,predicted_weight,color="maroon")
plt.xlabel("height")
plt.ylabel("weight")

plt.title('linear regression')
plt.show()
