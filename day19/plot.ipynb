# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = [2,3,4,5,7,11]
#create a plot
plt.plot(x,y)
#customization for the plot
#add a title'
plt.title('Line plot')
#add labels
plt.xlabel("x-axis")
plt.ylabel("y-axis")
#output the plot
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = [2,3,4,5,7,11]
plt.plot(x,y,marker='o',linestyle='-',color='b',markersize=6,
# Out:
#   Cell In[8], line 4
#     plt.plot(x,y,marker='0'),linestyle='-',color='b',markersor
#                              ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import matplotlib as pyplot as plot
x=[1,2,3,4,5]
y=[1,4,9,16,2]
y2=[1,2,2,3,3]
plt.plot(*x,y1,linestyle='_',color='b',linewidth=3,marker='o'
         marke


ply.frid(color-jre
